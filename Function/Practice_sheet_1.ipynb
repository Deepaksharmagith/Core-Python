# %% [markdown]
# <span style="color:yellow; font-size:25px;">1 to 5 Questions</span>

# %%
#1
country = ["USA","UK","India"]
heroes = ["Thor","Hulk"]

def print_len(list):
    print(len(list))

print_len(heroes)
print_len(country)

print(heroes[0], end="-")
print(heroes[1])

#using loop
def print_list(list):
    for items in list:
        print(items, end = " ")

print_list(country)
# Out:
# 2
# 3
# Thor-Hulk
# USA UK India

# %%
#2
#1 USD =83 INR
#2 USD =83*2 INR

def convert(USD_Value):
    INR_Val = USD_Value * 83
    print(USD_Value, "USD =", INR_Val, "INR" )

convert(100)
# Out:
# 100 USD = 8300 INR

# %%
#3
#n! =1x2x3-----n
#4! =1x2x3x4
n=5
fact=1
for i in range(1,n+1):
    fact*=i
print(fact)
# wrong   

def Cal_fact(n):
    fact=1
    for i in range(1,n+1):
        fact*=i
    print(fact)
Cal_fact(5)
# Out:
# 120
# 120

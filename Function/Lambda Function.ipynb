# %%
# def squ(X):
#     return X*X
# result = squ(5)
# print(result)

square = lambda x: x * x
print(square(5))
# Out:
# 25

# %%
sum= lambda a,b: a+b
print(sum(2,3))
# Out:
# 5

# %% [markdown]
# <span style="color:yellow; font-size:18px;">With map() from user</span>

# %% [markdown]
# <span style="color:yellow; font-size:18px;">With filter() from user</span>

# %%
num=[3,4,5,8,1]
even= list(filter(lambda x: x%2==0, num))
print(even)
# Out:
# [4, 8]

# %% [markdown]
# <span style="color:yellow; font-size:18px;">Sorting with Lambda</span>

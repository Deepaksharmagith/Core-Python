# %% [markdown]
# print()     # only print the 0/p
# return()    # return the o/p to the definitation

# %% [markdown]
# <span style="color:yellow; font-size:25px;">Take I/P from user</span>

# %%
def name(name):                              
    print("my name is:",name)   

a=input("enter a name")
name(a)
# Out:
# enter a name dee
# my name is: dee

# %%
def addition(a,b):
    c=a+b
    print(c)

x=int(input("a"))
y=int(input("b"))  
addition(x,y)
# Out:
# a 5
# b 6
# 11

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %%
# name, age, city = details() --> yee line Function se aaye multiple values ko, Ek hi line me alag-alag variables me store karti hai.
def details():                                        
    a=input("name")
    b=int(input("age"))
    c=input("city")
    return a,b,c 

name, age, city = details()
print()
print("My name is=",name)
print("My age is=",age)
print("My city is=",city)
# Out:
# name dee
# age 7
# city kh
# My name is= dee
# My age is= 7
# My city is= kh

# %%
def get():                                        
    a=input("name")
    b=int(input("age"))
    c=input("city")
    print(type(a))
    return a,b,c    #---> nothong will run after this line, program will end at return
    

get()
# Out:
# name g
# age 5
# city h
# <class 'str'>
# ('g', 5, 'h')

# %%
def get1():
    a=input("name")
    b=int(input("age"))
    c=input("city")
    print(a)
    print(b)
    print(c)
    print(type(a))

get1()
# Out:
# name h
# age 8
# city j
# h
# 8
# j
# <class 'str'>

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %%
# g is defined inside the function get(), so it is not accessible outside the function.

def get1():                                        
    g=input("name")
    print(g)
    
get1()
#print(g)   # so if i write here -->NameError: name 'a' is not defined
# Out:
# name gh
# gh

# %% [markdown]
# If you write two functions with the same name, the last one will overwrite the previous one.

# %%
def greet():
    print("Hello")

def greet():     # This overwrites the first greet()
    print("Hi")

greet()

# %% [markdown]
# <span style="color:yellow; font-size:25px;">Function without parameter</span>

# %%
# Create or Define Function 
def greetings():
    print("Welcome")

# Use or call above this(greetings) Function 
greetings()
# Out:
# Welcome

# %%
def greetings():
    print("Welcome")

# Use or call above this(greetings) Function 
A=greetings()
print(A) # A function that does not return anything gives None as output
# Out:
# Welcome
# None

# %% [markdown]
# <span style="color:yellow; font-size:25px;">Function with parameter</span>

# %%
def add2numbers(a,b):    # a, b is a parameter
    result = a + b
    print("The sum is: ", result)
    
# Calling this function with arguments                   (no of argu should be same as no of para..)
add2numbers(5,3)          # 5, 3 is a argument
add2numbers(b=52, a=3)
# Out:
# The sum is:  8
# The sum is:  55

# %% [markdown]
# <span style="color:yellow; font-size:30px;">Function with return statement</span>

# %%
def add2num(a,b):
    return a+b      # This line sends back sum of a and b (-->after return statement function ends nothing consider after this)

result = add2num(10,1)
print(result)
# Out:
# 11

# %%
# function to convert celsius to Fahrenheit- with return statement

def celsius_to_fahrenheit(celsius):
    fahrenheit = (celsius * 9/5) + 32
    return fahrenheit

#call function
temp_f = celsius_to_fahrenheit(25)
print(temp_f)
print("with return: ", type(temp_f))
# Out:
# 77.0
# with return:  <class 'float'>

# %%
# function to convert celsius to Fahrenheit- without return statement

def celsius_to_fahrenheit(celsius):
    fahrenheit = (celsius * 9/5) + 32 
    print(fahrenheit)
    print(type(fahrenheit))
    

#call function 
temp_f2 = celsius_to_fahrenheit(25) 
print("without return: ", type(temp_f2))
# Out:
# 77.0
# <class 'float'>
# without return:  <class 'NoneType'>

# %% [markdown]
# return statement--> we can use returned value of function for next time, as you can numerical data type is present, but after print no data type value shows.here we can perform multiple opperation on it like sum etc.
# without return statement--> but in this case we can't, here we just print the output value.

# %% [markdown]
# <span style="color:yellow; font-size:30px;">Using return result in another calculation </span>

# %%
def add(a,b):
    return a+b

result = add(2,3)
Final= result*2
print(Final)

A=Final+2
print(A)
# Out:
# 10
# 12

# %% [markdown]
# you can use printed data again.
# ---
# def add(a,b):
#     return a+b
#
# result = add(2,3)
# Final= result*2
# A=print(Final)
#
# new=A+2
# print(new)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %% [markdown]
# def add(a, b):
#     print(a + b)---> if i print here then what is it mean.
#
# result = add(5, 3)
#
# data print inside the function, so function is not able to returns any value to it's calling location, that why
# if i try to print "result" it gives "None"
# -------------------------------------------------------------
# def add(a, b):
#     return a + b
#
# result = add(5, 3)
# print(result) --->if i print here then what is it mean
#
# here function returns a value to the calling location (result) so result stores =8
# Now it's your choice , you want to print it or reuse it for further calculation
# ----

# %%
def is_even(num):
    return num % 2==0

No = is_even(10)
if No is True:
    print("Even")
#-------------------------------------

def is_even(num):
    return num % 2 == 0

if is_even(10):
    print("Even number")
else:
    print("odd number")
# Out:
# Even
# Even number

# %%
# use Cube value for square function
def square(x):
    return x * x

def cube(x):
    return x * square(x)

Cube = cube(3)
print(Cube)

Square = square(Cube)
print(Square)
# Out:
# 27
# 729

# %% [markdown]
# <span style="color:yellow; font-size:30px;">Pass Statement </span>

# %%
def kuchbhi(): 


print("Hello!")
# Out:
#   Cell In[6], line 4
#     print("Hello!")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def kuchbhi():  
    pass        # code to be updated later


print("Hello!")
# Out:
# Hello!

# %% [markdown]
# <span style="color:yellow; font-size:30px;">Types of Function Arguments </span>

# %% [markdown]
# <span style="color:yellow; font-size:30px;">1. Required Arguments (single/multiple arguments) </span>

# %%
def greetings(name):        # name is parameter
    print("Hello ", name, "!") 

greetings("Madhav")     # Madhav is argument 
#greetings()           # TypeError: greetings() missing 1 required positional argument: 'name'
# Out:
# Hello  Madhav !

# %%
def intro(course_name, instructor_name):
    print("Welcome to ", course_name, "course by", instructor_name)

intro("Python", "Deepak")
# Out:
# Welcome to  Python course by Deepak

# %% [markdown]
# <span style="color:yellow; font-size:30px;">2. Default Arguments </span>

# %%
def greetings(name = "World"):        # "World" is a default value
    print("Hello ", name, "!") 

greetings()     # runs without error using default value , if there is no argument given,then function will use default argument.
greetings("Rishabh")
# Out:
# Hello  World !
# Hello  Rishabh !

# %%
def cal(a,b=2):
    add= a+b
    print(add)
#cal(1)
#cal(a=1, b) #error--> positional argument follows keyword argument (phle non-default argument aana chahiya)
cal(a=1) #no argument pass then default value runs
cal(a=1, b=4)
# Out:
# 3
# 5

# %% [markdown]
# <span style="color:yellow; font-size:30px;">3. positional argument or Keyword Arguments (named argument)</span>
#   (called bez here we use key to define a value)

# %%
def divide(a,b):
    return a/b

result1 = divide(100,10)     #--->This is positional argument (by default a ko 100, b=10 assume kr lega)
print(result1)

result2 = divide(b = 100,a = 20)   #--->This is keyword argument
print(result2)
# Out:
# 10.0
# 0.2

# %% [markdown]
# <span style="color:yellow; font-size:30px;">4. Arbitrary Argument
# </span>

# %% [markdown]
# Arbitrary Positional Argument (*args)   -->stores arguments as tuple

# %%
# if we don't know how many arguments need to pass. Berore we did like this
def add2number(a,b):
    return a+b

result = add2number(10,11)
print(result)

def add3number(a,b,c):
    return a+b+c

result1 = add3number(10,11,1)
print(result1)
# Out:
# 21
# 22

# %% [markdown]
# def add2number(a,b):
#     #return a+b
#     return sum(a,b)
#
# result = add2number(10,11)
# print(result)
#
# -------------------------------------------
#
# def add_numbers(*args):
#     return sum(args)
#
# op = add_numbers(1,2,3,4)
# print(op)
#
# --------------------------------------------
# Q--> In 1st code i was not able to use sum function but in 2nd code i can use. why i can not use in 1st code?
#
# Because sum() does NOT take two numbers like this:
# Actual meaning of sum() is:
# sum(iterable, start=0)
# First argument(iterable) → must be a collection (list, tuple, etc.)
# Second argument → optional starting value
#
# In 2nd code--> All data stored in Touple.

# %% [markdown]
# NOW

# %%
def add_numbers(*args):
    print(type(args))
    return sum(args)

op = add_numbers(1,2,3,4)   # variable no. of arguments
print(op)
# Out:
# <class 'tuple'>
# 10

# %%
def greetings2(*names):
    for namee in names:
        print(f"Hello, {namee}!")
    print(type(namee))

#OR

greetings2("Madhav", 'Rishabh', 'Visakha')

def greetings3(*names):
    print(f"Hello, {namee}!")
    print(type(namee))
        

greetings2("Madhav", 'Rishabh', 'Visakha')
# Out:
# Hello, Madhav!
# Hello, Rishabh!
# Hello, Visakha!
# <class 'str'>
# Hello, Madhav!
# Hello, Rishabh!
# Hello, Visakha!
# <class 'str'>

# %%
def greetings2(*names):
    for namee in names:
        print(f"Hello, {namee}!")
    print(type(namee))

# %% [markdown]
# <span style="color:yellow; font-size:30px;">5. Arbitrary Keyword Argument (**kwargs)</span>
#  Note: stores arguments as dictionary, here we pass keys to argument.

# %%
def print_details(**kwargs):
    # print(type(kwargs))       # dictionary type
    for key, value in kwargs.items():
        print(f"{key}: {value}") 

print_details(name = "Madhav", age = 26, city = "Delhi")
# Out:
# name: Madhav
# age: 26
# city: Delhi

# %%
def shopping_cart(**products): 
    total = 0 
    print("Items Purchased:") 
    for item, price in products.items(): 
        print(f"{item}: ₹{price}") 
        total += price 
    print(f"Total: ₹{total}") 
 
# multiple keyword arguments 
shopping_cart(apple=15, orange=12, mango=10)
# Out:
# Items Purchased:
# apple: ₹15
# orange: ₹12
# mango: ₹10
# Total: ₹37

# %% [markdown]
# <span style="color:Green; font-size:25px;">Part-1--> 10 Questions</span>

# %% [markdown]
# 1. separate prime no from composit no from a list and store them inside to different list.
# 2. Searching a number from list
# 3. Store reverse of a list
# 4. Escape Multiple NO, using list

# %%
#1 separate prime no from composit no from a list and store them inside to different list.

# %%
#2 Searching a number from list 

l=[]
size=int(input("enter the size of list"))
for i in range(0,size):
    l.append(int(input("enter the element")))
print(l)

# %%
search=int(input("enter the search no"))
found=False
for k in l:
    if(k==search):
        break
if(found):
    print("search element found")
else:
    print("search element not found")

# %%
# Easy way
l=[]
size=int(input("enter the size of list"))
for i in range(0,size):
    l.append(int(input()))

n=int(input("enter the search no"))    
if(n in l):
    print("search element found")
else:
    print("search element not found")

# %%
#3 Store reverse of a list

# %%
#4 Escape Multiple NO, using list

# %% [markdown]
# <span style="color:yellow; font-size:25px;">Types of sorting</span>

# %% [markdown]
# Bubble sort
#
# program to sort data of a list in a ascending order using bubble sort

# %% [markdown]
# Insertion sorts
